# %%
import pandas as pd

# %%
df = pd.read_csv("dataset.csv")

# %%
df.groupby(by= ["country"]).sum().sort_values("cases", ascending=False).reset_index().to_csv("lista.csv", index=False)

# %%
ddd

# %%
df
# Out:
#        day  month  year  cases  deaths      country     pop2019 continent  \
# 0       14     12  2020    746       6  Afghanistan  38041757.0      Asia
# 1       13     12  2020    298       9  Afghanistan  38041757.0      Asia
# 2       12     12  2020    113      11  Afghanistan  38041757.0      Asia
# 3       11     12  2020     63      10  Afghanistan  38041757.0      Asia
# 4       10     12  2020    202      16  Afghanistan  38041757.0      Asia
# ...    ...    ...   ...    ...     ...          ...         ...       ...
# 61895   25      3  2020      0       0     Zimbabwe  14645473.0    Africa
# 61896   24      3  2020      0       1     Zimbabwe  14645473.0    Africa
# 61897   23      3  2020      0       0     Zimbabwe  14645473.0    Africa
# 61898   22      3  2020      1       0     Zimbabwe  14645473.0    Africa
# 61899   21      3  2020      1       0     Zimbabwe  14645473.0    Africa
#
#       cum14daysCasesPer100000
# 0                  9.01377925
# ...

# %%
'''def sostituzione(elemento):
    dizionario = {1:"Gen", 2: "Feb", 3:"Mar", 4:"Apr", 5:"Mag", 6:"Giu", 7:"Lug", 8:"Ago", 9:"Set", 10:"Ott", 11:"Nov", 12:"Dic"}
    return dizionario[elemento]
'''
# Out:
# 'def sostituzione(elemento):\n    dizionario = {1:"Gen", 2: "Feb", 3:"Mar", 4:"Apr", 5:"Mag", 6:"Giu", 7:"Lug", 8:"Ago", 9:"Set", 10:"Ott", 11:"Nov", 12:"Dic"}\n    return dizionario[elemento]\n'

# %%
#df["month"] = df.month.apply(sostituzione)

# %%
df = df.drop(columns=["cum14daysCasesPer100000"], axis =1)

# %%
df = df.loc[(df.continent =="Europe") & (df.notna().index)].reset_index(drop = True)

# %%
df
# Out:
#       day  month  year  cases  deaths         country     pop2019 continent
# 0      13     12  2020    879      12         Albania   2862427.0    Europe
# 1      11     12  2020    873      14         Albania   2862427.0    Europe
# 2       9     12  2020    753      14         Albania   2862427.0    Europe
# 3       7     12  2020    840      16         Albania   2862427.0    Europe
# 4       5     12  2020    801      18         Albania   2862427.0    Europe
# ...   ...    ...   ...    ...     ...             ...         ...       ...
# 8681    8      1  2020      0       0  United_Kingdom  66647112.0    Europe
# 8682    6      1  2020      0       0  United_Kingdom  66647112.0    Europe
# 8683    4      1  2020      0       0  United_Kingdom  66647112.0    Europe
# 8684    2      1  2020      0       0  United_Kingdom  66647112.0    Europe
# 8685   31     12  2019      0       0  United_Kingdom  66647112.0    Europe
#
# [8686 rows x 8 columns]

# %%
df["date"] = pd.to_datetime(df.day.apply(lambda x: str(x)+ "/") + df.month.apply(lambda x: str(x)+"/") +df.year.apply(lambda x: str(x)))
# Out:
# c:\Users\tommy\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/12/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# c:\Users\tommy\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/11/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# c:\Users\tommy\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/11/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
df = df.drop(columns=["day", "month", "year", "pop2019"])

# %%
df2= df.groupby(by=["country", "date"]).sum(["cases", "deaths"])

# %%
df2 = df2.reset_index()

# %%
df2
# Out:
#              country       date  cases  deaths
# 0            Albania 2020-01-04     20       3
# 1            Albania 2020-01-05      7       0
# 2            Albania 2020-01-08     79       3
# 3            Albania 2020-01-11    241       7
# 4            Albania 2020-01-12    557      12
# ...              ...        ...    ...     ...
# 8681  United_Kingdom 2020-12-06   1199      76
# 8682  United_Kingdom 2020-12-07    565      17
# 8683  United_Kingdom 2020-12-09   3539       6
# 8684  United_Kingdom 2020-12-10  12872      65
# 8685  United_Kingdom 2020-12-13  21501     520
#
# [8686 rows x 4 columns]

# %%
df3 = df2.groupby(by="date").sum(["cases", "deaths"]).reset_index()

# %%
df3["cases"] = df3.cases.cumsum()

# %%
df3["deaths"]  =df3.deaths.cumsum()

# %%
df3 = df3.iloc[1:]

# %%
df3
# Out:
#           date     cases  deaths
# 1   2020-01-01         0       0
# 2   2020-01-02         5       0
# 3   2020-01-03       285       8
# 4   2020-01-04     28918    2167
# 5   2020-01-05     41038    3744
# ..         ...       ...     ...
# 345 2020-12-10  10280591  229090
# 346 2020-12-11  10383630  231003
# 347 2020-12-12  10472793  233265
# 348 2020-12-13  10594684  235745
# 349 2020-12-14  10694864  237483
#
# [349 rows x 3 columns]

# %%
df3.to_csv("generale_giorno.csv", index=False)

# %%
lista = ['Russia',
 'France',
 'Italy',
 'United_Kingdom',
 'Spain',
 'Germany',
 'Poland',
 'Turkey',
 'Ukraine',
 'Belgium']

# %%
df
# Out:
#       cases  deaths         country continent       date
# 0       879      12         Albania    Europe 2020-12-13
# 1       873      14         Albania    Europe 2020-11-12
# 2       753      14         Albania    Europe 2020-09-12
# 3       840      16         Albania    Europe 2020-07-12
# 4       801      18         Albania    Europe 2020-05-12
# ...     ...     ...             ...       ...        ...
# 8681      0       0  United_Kingdom    Europe 2020-08-01
# 8682      0       0  United_Kingdom    Europe 2020-06-01
# 8683      0       0  United_Kingdom    Europe 2020-04-01
# 8684      0       0  United_Kingdom    Europe 2020-02-01
# 8685      0       0  United_Kingdom    Europe 2019-12-31
#
# [8686 rows x 5 columns]

# %%
df = df.loc[df.country.isin(lista)].reset_index(drop=True)

# %%
df.sort_values(by=["date",  "cases"], ascending=False).reset_index(drop=True).to_csv("paesi_giorno", index=False)

# %%
df.sort_values(by=["date",  "deaths"], ascending=False).reset_index(drop=True).to_csv("paesi_deaths_giorno", index=False)
